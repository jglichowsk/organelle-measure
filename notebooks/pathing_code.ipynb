# %%
from pathlib import Path
import numpy as np
from skimage import io

# %%
process_dir=Path.cwd() #if python file located in Scripts subfolder, will return that as current directory. 
#Processing scripts will need to locate image files in Images folder, which is upstream twice and then back down one. 
orgmeasure_dir=process_dir.parents[1] #upstream twice...
image_dir=orgmeasure_dir.__str__() + '\\images' #and back down one. Define image directory variable using dunder string.

# %%
tmask_path=r'C:\Users\jglic\OneDrive - Washington University in St. Louis\Documents\School\WashU\Mukherji Lab\Experiments\Diploid Live Imaging\segm-mask-test.tif'

# %%
tmask=io.imread(tmask_path)
np.shape(tmask)
# Out:
# (24, 1492, 1806)

# %%
import matplotlib.pyplot as plt

# %%
io.imshow(tmask[12,:,:])
plt.show()
# Out:
# c:\Python310\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:149: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)
